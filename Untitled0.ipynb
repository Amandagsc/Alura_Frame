# %% [markdown]
# <a href="https://colab.research.google.com/github/Amandagsc/Alura_Frame/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
senha = ''
while senha != '123':
  senha = input('Qual é a senha do sistema? ')
  print('senha errada!')
print('Acesso Liberado!')
# Out:
# Qual é a senha do sistema? 147
# senha errada!
# Qual é a senha do sistema? 123
# senha errada!
# Acesso Liberado!
