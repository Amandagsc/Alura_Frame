# %% [markdown]
# <a href="https://colab.research.google.com/github/Amandagsc/Alura_Frame/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tarefas = []
tarefas.append('Estudar Python com IA''c')
tarefas.append('Ler um artigo sofre IA')
tarefas.append('Responder e-mails')
print(tarefas)
# Out:
# ['Estudar Python com IAc', 'Ler um artigo sofre IA', 'Responder e-mails']
